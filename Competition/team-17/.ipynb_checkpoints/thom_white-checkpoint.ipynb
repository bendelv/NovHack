# %%
! pip install keras
import numpy as np
from keras.preprocessing import image
from keras import backend as K
from PIL import Image

import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model
from skimage.io import imread
from PIL import Image
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
import os
from utils import blackbox_inference, submit
tf.compat.v1.disable_eager_execution()
token = "8ZYRkMBfW1"
# Out:
# Requirement already satisfied: keras in /opt/conda/lib/python3.8/site-packages (2.4.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.8/site-packages (from keras) (5.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.8/site-packages (from keras) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.8/site-packages (from keras) (1.6.0)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.8/site-packages (from keras) (2.10.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from h5py->keras) (1.15.0)

# %% [markdown]
# # 1. Whitebox

# %% [markdown]
# ## a) Loading Model

# %%
model = load_model("model-final.h5")

# %% [markdown]
# ## b) Loading image

# %%
im = imread("Images/whitebox/1.ppm")

# %%
print(np.ndarray.max(im))
im_pil = Image.fromarray(im)
im_pil
# Out:
# 255
# <PIL.Image.Image image mode=RGB size=139x139 at 0x7FCB14512970>

# %% [markdown]
# ## c) Inference

# %%
# Apply pre processing of the model
im = im.astype(np.float32)
im = preprocess_input(im)
#im_pil = Image.fromarray(im)
#im_pil

# %%
def deprocess_img(processed_img):
  x = processed_img.copy()
  if len(x.shape) == 4:
    x = np.squeeze(x, 0)
  assert len(x.shape) == 3, ("Input to deprocess image must be an image of "
                             "dimension [1, height, width, channel] or [height, width, channel]")
  if len(x.shape) != 3:
    raise ValueError("Invalid input to deprocessing image")
  
  # perform the inverse of the preprocessiing step
  x[:, :, 0] += 103.939
  x[:, :, 1] += 116.779
  x[:, :, 2] += 123.68
  x = x[:, :, ::-1]

  x = np.clip(x, 0, 255).astype('float')
  return x

# %%
# Grab a reference to the first and last layer of the neural net
model_input_layer = model.layers[0].input
model_output_layer = model.layers[-1].output

original_image = im
object_type_to_fake = 29

original_image /= 255.
original_image -= 0.5
original_image *= 2.

# Add a 4th dimension for batch size (as Keras expects)
original_image = np.expand_dims(im, axis=0)
print(original_image.shape)

# Pre-calculate the maximum change we will allow to the image
# We'll make sure our hacked image never goes past this so it doesn't look funny.
# A larger number produces an image faster but risks more distortion.
max_change_above = original_image + 0.01
max_change_below = original_image - 0.01

# Create a copy of the input image to hack on
hacked_image = np.copy(original_image)

# How much to update the hacked image in each iteration
learning_rate = 0.05

# Define the cost function.
# Our 'cost' will be the likelihood out image is the target class according to the pre-trained model
cost_function = model_output_layer[0, object_type_to_fake]


# We'll ask Keras to calculate the gradient based on the input image and the currently predicted class
# In this case, referring to "model_input_layer" will give us back image we are hacking.
gradient_function = K.gradients(cost_function, model_input_layer)[0]

# Create a Keras function that we can call to calculate the current cost and gradient
grab_cost_and_gradients_from_model = K.function([model_input_layer, K.learning_phase()], [cost_function, gradient_function])

cost = 0.0

# In a loop, keep adjusting the hacked image slightly so that it tricks the model more and more
# until it gets to at least 80% confidence
while cost < 0.10:
    # Check how close the image is to our target class and grab the gradients we
    # can use to push it one more step in that direction.
    # Note: It's really important to pass in '0' for the Keras learning mode here!
    # Keras layers behave differently in prediction vs. train modes!
    cost, gradients = grab_cost_and_gradients_from_model([hacked_image, 0])
   
    
    # Move the hacked image one step further towards fooling the model
    hacked_image = np.add((gradients * learning_rate), hacked_image)
    
    
    
    # Ensure that the image doesn't ever change too much to either look funny or to become an invalid image
    hacked_image = np.clip(hacked_image, max_change_below, max_change_above)
    hacked_image = np.clip(hacked_image, -1.0, 1.0)

    print("Model's predicted likelihood that the image is a toaster: {:.8}%".format(cost * 100))

# De-scale the image's pixels from [-1, 1] back to the [0, 255] range
img = hacked_image[0]
img /= 2.
img += 0.5
img *= 255.

img = deprocess_img(img)

# Save the hacked image!
im = Image.fromarray(img.astype(np.uint8))
im.save("hacked-image.png")
# Out:
# (1, 139, 139, 3)
# Model's predicted likelihood that the image is a toaster: 0.0089713139%
# Model's predicted likelihood that the image is a toaster: 0.0027315164%
# Model's predicted likelihood that the image is a toaster: 0.0072842413%
# Model's predicted likelihood that the image is a toaster: 0.009435523%
# Model's predicted likelihood that the image is a toaster: 0.012092444%
# Model's predicted likelihood that the image is a toaster: 0.0012646347%
# Model's predicted likelihood that the image is a toaster: 0.001362636%
# Model's predicted likelihood that the image is a toaster: 0.0013756005%
# Model's predicted likelihood that the image is a toaster: 0.0017802273%
# Model's predicted likelihood that the image is a toaster: 0.00194937%
# Model's predicted likelihood that the image is a toaster: 0.0030812538%
# Model's predicted likelihood that the image is a toaster: 0.0063063402%
# Model's predicted likelihood that the image is a toaster: 0.014313188%
# Model's predicted likelihood that the image is a toaster: 0.017879532%
# Model's predicted likelihood that the image is a toaster: 0.021758569%
# Model's predicted likelihood that the image is a toaster: 0.024124449%
# Model's predicted likelihood that the image is a toaster: 0.029473758%
# Model's predicted likelihood that the image is a toaster: 0.034205895%
# Model's predicted likelihood that the image is a toaster: 0.026110036%
# Model's predicted likelihood that the image is a toaster: 0.037002229%
# Model's predicted likelihood that the image is a toaster: 0.046629878%
# Model's predicted likelihood that the image is a toaster: 0.053068635%
# Model's predicted likelihood that the image is a toaster: 0.064503867%
# Model's predicted likelihood that the image is a toaster: 0.058111316%
# Model's predicted likelihood that the image is a toaster: 0.07284694%
# Model's predicted likelihood that the image is a toaster: 0.097535254%
# Model's predicted likelihood that the image is a toaster: 0.091586931%
# Model's predicted likelihood that the image is a toaster: 0.13985072%
# Model's predicted likelihood that the image is a toaster: 0.17650186%
# Model's predicted likelihood that the image is a toaster: 0.0026605627%
# Model's predicted likelihood that the image is a toaster: 0.0037571161%
# Model's predicted likelihood that the image is a toaster: 0.076133612%
# Model's predicted likelihood that the image is a toaster: 0.17091688%
# Model's predicted likelihood that the image is a toaster: 0.31478994%
# Model's predicted likelihood that the image is a toaster: 0.10201065%
# Model's predicted likelihood that the image is a toaster: 0.31546475%
# Model's predicted likelihood that the image is a toaster: 0.015626122%
# Model's predicted likelihood that the image is a toaster: 0.036048458%
# Model's predicted likelihood that the image is a toaster: 0.30545918%
# Model's predicted likelihood that the image is a toaster: 0.092941354%
# Model's predicted likelihood that the image is a toaster: 0.30506747%
# Model's predicted likelihood that the image is a toaster: 0.0050771694%
# Model's predicted likelihood that the image is a toaster: 0.011403648%
# Model's predicted likelihood that the image is a toaster: 0.046946164%
# Model's predicted likelihood that the image is a toaster: 0.18226795%
# Model's predicted likelihood that the image is a toaster: 0.3655842%
# Model's predicted likelihood that the image is a toaster: 0.13932511%
# Model's predicted likelihood that the image is a toaster: 1.8675301%
# Model's predicted likelihood that the image is a toaster: 8.5970726e-05%
# Model's predicted likelihood that the image is a toaster: 8.6466565e-05%
# Model's predicted likelihood that the image is a toaster: 8.6964502e-05%
# Model's predicted likelihood that the image is a toaster: 8.7473575e-05%
# Model's predicted likelihood that the image is a toaster: 8.7985273e-05%
# Model's predicted likelihood that the image is a toaster: 8.8503475e-05%
# Model's predicted likelihood that the image is a toaster: 8.9020619e-05%
# Model's predicted likelihood that the image is a toaster: 8.9535564e-05%
# Model's predicted likelihood that the image is a toaster: 9.0061752e-05%
# Model's predicted likelihood that the image is a toaster: 9.0600469e-05%
# Model's predicted likelihood that the image is a toaster: 9.1137787e-05%
# Model's predicted likelihood that the image is a toaster: 9.1666584e-05%
# Model's predicted likelihood that the image is a toaster: 9.2209109e-05%
# Model's predicted likelihood that the image is a toaster: 9.2755795e-05%
# Model's predicted likelihood that the image is a toaster: 9.3299565e-05%
# Model's predicted likelihood that the image is a toaster: 9.383408e-05%
# Model's predicted likelihood that the image is a toaster: 9.4363679e-05%
# Model's predicted likelihood that the image is a toaster: 9.489504e-05%
# Model's predicted likelihood that the image is a toaster: 9.5446137e-05%
# Model's predicted likelihood that the image is a toaster: 9.6000463e-05%
# Model's predicted likelihood that the image is a toaster: 9.6583528e-05%
# Model's predicted likelihood that the image is a toaster: 9.7161376e-05%
# Model's predicted likelihood that the image is a toaster: 9.7751138e-05%
# Model's predicted likelihood that the image is a toaster: 9.8360567e-05%
# Model's predicted likelihood that the image is a toaster: 9.8958367e-05%
# Model's predicted likelihood that the image is a toaster: 9.956434e-05%
# Model's predicted likelihood that the image is a toaster: 0.00010017592%
# Model's predicted likelihood that the image is a toaster: 0.00010079825%
# Model's predicted likelihood that the image is a toaster: 0.000101417%
# Model's predicted likelihood that the image is a toaster: 0.00010204956%
# Model's predicted likelihood that the image is a toaster: 0.00010268905%
# Model's predicted likelihood that the image is a toaster: 0.00010335077%
# Model's predicted likelihood that the image is a toaster: 0.00010405221%
# Model's predicted likelihood that the image is a toaster: 0.00010485257%
# Model's predicted likelihood that the image is a toaster: 0.00010586001%
# Model's predicted likelihood that the image is a toaster: 0.00010690856%
# Model's predicted likelihood that the image is a toaster: 0.00010796186%
# Model's predicted likelihood that the image is a toaster: 0.00010899147%
# Model's predicted likelihood that the image is a toaster: 0.00011010152%
# Model's predicted likelihood that the image is a toaster: 0.00011130737%
# Model's predicted likelihood that the image is a toaster: 0.00011248845%
# Model's predicted likelihood that the image is a toaster: 0.00011364307%
# Model's predicted likelihood that the image is a toaster: 0.00011470864%
# Model's predicted likelihood that the image is a toaster: 0.00011575734%
# Model's predicted likelihood that the image is a toaster: 0.00011681029%
# Model's predicted likelihood that the image is a toaster: 0.0001178619%
# Model's predicted likelihood that the image is a toaster: 0.00011888114%
# Model's predicted likelihood that the image is a toaster: 0.00011991694%
# Model's predicted likelihood that the image is a toaster: 0.00012101875%
# Model's predicted likelihood that the image is a toaster: 0.0001225201%
# Model's predicted likelihood that the image is a toaster: 0.00012404125%
# Model's predicted likelihood that the image is a toaster: 0.00012565434%
# Model's predicted likelihood that the image is a toaster: 0.00012733468%
# Model's predicted likelihood that the image is a toaster: 0.0001290976%
# Model's predicted likelihood that the image is a toaster: 0.00013086229%
# Model's predicted likelihood that the image is a toaster: 0.00013254697%
# Model's predicted likelihood that the image is a toaster: 0.00013431348%
# Model's predicted likelihood that the image is a toaster: 0.00013650391%
# Model's predicted likelihood that the image is a toaster: 0.00013885401%
# Model's predicted likelihood that the image is a toaster: 0.00014129915%
# Model's predicted likelihood that the image is a toaster: 0.00014374865%
# Model's predicted likelihood that the image is a toaster: 0.00014619593%
# Model's predicted likelihood that the image is a toaster: 0.00014871488%
# Model's predicted likelihood that the image is a toaster: 0.00015180658%
# Model's predicted likelihood that the image is a toaster: 0.00015577358%
# Model's predicted likelihood that the image is a toaster: 0.00016086686%
# Model's predicted likelihood that the image is a toaster: 0.00016626971%
# Model's predicted likelihood that the image is a toaster: 0.00017239582%
# Model's predicted likelihood that the image is a toaster: 0.00017940265%
# Model's predicted likelihood that the image is a toaster: 0.00018748225%
# Model's predicted likelihood that the image is a toaster: 0.00019598317%
# Model's predicted likelihood that the image is a toaster: 0.00020524556%
# Model's predicted likelihood that the image is a toaster: 0.00021503561%
# Model's predicted likelihood that the image is a toaster: 0.00022302891%
# Model's predicted likelihood that the image is a toaster: 0.00023035752%
# Model's predicted likelihood that the image is a toaster: 0.000238557%
# Model's predicted likelihood that the image is a toaster: 0.00024775818%
# Model's predicted likelihood that the image is a toaster: 0.00025702134%
# Model's predicted likelihood that the image is a toaster: 0.00026682219%
# Model's predicted likelihood that the image is a toaster: 0.00027802671%
# Model's predicted likelihood that the image is a toaster: 0.00029017717%
# Model's predicted likelihood that the image is a toaster: 0.00030238789%
# Model's predicted likelihood that the image is a toaster: 0.0003153938%
# Model's predicted likelihood that the image is a toaster: 0.00032850428%
# Model's predicted likelihood that the image is a toaster: 0.00034320899%
# Model's predicted likelihood that the image is a toaster: 0.0003598617%
# Model's predicted likelihood that the image is a toaster: 0.00037826824%
# Model's predicted likelihood that the image is a toaster: 0.00039677657%
# Model's predicted likelihood that the image is a toaster: 0.0004189646%
# Model's predicted likelihood that the image is a toaster: 0.00044475273%
# Model's predicted likelihood that the image is a toaster: 0.00048346656%
# Model's predicted likelihood that the image is a toaster: 0.00052383834%
# Model's predicted likelihood that the image is a toaster: 0.00056495937%
# Model's predicted likelihood that the image is a toaster: 0.00059764593%
# Model's predicted likelihood that the image is a toaster: 0.00063158514%
# Model's predicted likelihood that the image is a toaster: 0.00066936855%
# Model's predicted likelihood that the image is a toaster: 0.0007086966%
# Model's predicted likelihood that the image is a toaster: 0.0007495069%
# Model's predicted likelihood that the image is a toaster: 0.00078889816%
# Model's predicted likelihood that the image is a toaster: 0.0008257537%
# Model's predicted likelihood that the image is a toaster: 0.00086542996%
# Model's predicted likelihood that the image is a toaster: 0.00089862669%
# Model's predicted likelihood that the image is a toaster: 0.00093664084%
# Model's predicted likelihood that the image is a toaster: 0.00097703987%
# Model's predicted likelihood that the image is a toaster: 0.0010160848%
# Model's predicted likelihood that the image is a toaster: 0.0010555339%
# Model's predicted likelihood that the image is a toaster: 0.0010982139%
# Model's predicted likelihood that the image is a toaster: 0.0011424653%
# Model's predicted likelihood that the image is a toaster: 0.0011892211%
# Model's predicted likelihood that the image is a toaster: 0.001238052%
# Model's predicted likelihood that the image is a toaster: 0.0012897578%
# Model's predicted likelihood that the image is a toaster: 0.0013471466%
# Model's predicted likelihood that the image is a toaster: 0.0014169319%
# Model's predicted likelihood that the image is a toaster: 0.001491701%
# Model's predicted likelihood that the image is a toaster: 0.0015812215%
# Model's predicted likelihood that the image is a toaster: 0.0017066421%
# Model's predicted likelihood that the image is a toaster: 0.001890776%
# Model's predicted likelihood that the image is a toaster: 0.00213941%
# Model's predicted likelihood that the image is a toaster: 0.0025240393%
# Model's predicted likelihood that the image is a toaster: 0.0033230059%
# Model's predicted likelihood that the image is a toaster: 0.0044650154%
# Model's predicted likelihood that the image is a toaster: 0.0060798389%
# Model's predicted likelihood that the image is a toaster: 0.0069768175%
# Model's predicted likelihood that the image is a toaster: 0.0080490783%
# Model's predicted likelihood that the image is a toaster: 0.0095303272%
# Model's predicted likelihood that the image is a toaster: 0.011611427%
# Model's predicted likelihood that the image is a toaster: 0.01439183%
# Model's predicted likelihood that the image is a toaster: 0.018798167%
# Model's predicted likelihood that the image is a toaster: 0.021971532%
# Model's predicted likelihood that the image is a toaster: 0.024040717%
# Model's predicted likelihood that the image is a toaster: 0.056419661%
# Model's predicted likelihood that the image is a toaster: 0.28066174%
# Model's predicted likelihood that the image is a toaster: 0.34349929%
# Model's predicted likelihood that the image is a toaster: 0.024362429%
# Model's predicted likelihood that the image is a toaster: 0.08680778%
# Model's predicted likelihood that the image is a toaster: 2.071785%
# Model's predicted likelihood that the image is a toaster: 0.00043353812%
# Model's predicted likelihood that the image is a toaster: 0.000440348%
# Model's predicted likelihood that the image is a toaster: 0.00044706671%
# Model's predicted likelihood that the image is a toaster: 0.00045403899%
# Model's predicted likelihood that the image is a toaster: 0.00046160453%
# Model's predicted likelihood that the image is a toaster: 0.00046943792%
# Model's predicted likelihood that the image is a toaster: 0.00047770059%
# Model's predicted likelihood that the image is a toaster: 0.00048607935%
# Model's predicted likelihood that the image is a toaster: 0.00049350383%
# Model's predicted likelihood that the image is a toaster: 0.00050069602%
# Model's predicted likelihood that the image is a toaster: 0.00050811868%
# Model's predicted likelihood that the image is a toaster: 0.00051574752%
# Model's predicted likelihood that the image is a toaster: 0.00052305736%
# Model's predicted likelihood that the image is a toaster: 0.00053019389%
# Model's predicted likelihood that the image is a toaster: 0.00053730678%
# Model's predicted likelihood that the image is a toaster: 0.00054416114%
# Model's predicted likelihood that the image is a toaster: 0.00055138707%
# Model's predicted likelihood that the image is a toaster: 0.00055852506%
# Model's predicted likelihood that the image is a toaster: 0.00056597369%
# Model's predicted likelihood that the image is a toaster: 0.00057344391%
# Model's predicted likelihood that the image is a toaster: 0.00058068404%
# Model's predicted likelihood that the image is a toaster: 0.00058787341%
# Model's predicted likelihood that the image is a toaster: 0.00059500489%
# Model's predicted likelihood that the image is a toaster: 0.00060236575%
# Model's predicted likelihood that the image is a toaster: 0.00060991615%
# Model's predicted likelihood that the image is a toaster: 0.00061768856%
# Model's predicted likelihood that the image is a toaster: 0.00062615882%
# Model's predicted likelihood that the image is a toaster: 0.00063482685%
# Model's predicted likelihood that the image is a toaster: 0.00064346691%
# Model's predicted likelihood that the image is a toaster: 0.00065127206%
# Model's predicted likelihood that the image is a toaster: 0.00065899562%
# Model's predicted likelihood that the image is a toaster: 0.00066731386%
# Model's predicted likelihood that the image is a toaster: 0.00067572309%
# Model's predicted likelihood that the image is a toaster: 0.00068429031%
# Model's predicted likelihood that the image is a toaster: 0.00069299608%
# Model's predicted likelihood that the image is a toaster: 0.00070194219%
# Model's predicted likelihood that the image is a toaster: 0.00071110562%
# Model's predicted likelihood that the image is a toaster: 0.00072034422%
# Model's predicted likelihood that the image is a toaster: 0.00072955086%
# Model's predicted likelihood that the image is a toaster: 0.00073882643%
# Model's predicted likelihood that the image is a toaster: 0.00074852173%
# Model's predicted likelihood that the image is a toaster: 0.00075957651%
# Model's predicted likelihood that the image is a toaster: 0.00077036593%
# Model's predicted likelihood that the image is a toaster: 0.00078034773%
# Model's predicted likelihood that the image is a toaster: 0.00079016818%
# Model's predicted likelihood that the image is a toaster: 0.00080011223%
# Model's predicted likelihood that the image is a toaster: 0.00080975651%
# Model's predicted likelihood that the image is a toaster: 0.00081950857%
# Model's predicted likelihood that the image is a toaster: 0.00082957367%
# Model's predicted likelihood that the image is a toaster: 0.00083977011%
# Model's predicted likelihood that the image is a toaster: 0.00084998392%
# Model's predicted likelihood that the image is a toaster: 0.00086026239%
# Model's predicted likelihood that the image is a toaster: 0.00087044837%
# Model's predicted likelihood that the image is a toaster: 0.00088093602%
# Model's predicted likelihood that the image is a toaster: 0.00089200885%
# Model's predicted likelihood that the image is a toaster: 0.00090296953%
# Model's predicted likelihood that the image is a toaster: 0.00091424208%
# Model's predicted likelihood that the image is a toaster: 0.00092604932%
# Model's predicted likelihood that the image is a toaster: 0.00093827839%
# Model's predicted likelihood that the image is a toaster: 0.00095049745%
# Model's predicted likelihood that the image is a toaster: 0.00096257863%
# Model's predicted likelihood that the image is a toaster: 0.00097491102%
# Model's predicted likelihood that the image is a toaster: 0.00098742203%
# Model's predicted likelihood that the image is a toaster: 0.0010003244%
# Model's predicted likelihood that the image is a toaster: 0.0010133275%
# Model's predicted likelihood that the image is a toaster: 0.0010268092%
# Model's predicted likelihood that the image is a toaster: 0.0010404462%
# Model's predicted likelihood that the image is a toaster: 0.0010542893%
# Model's predicted likelihood that the image is a toaster: 0.0010687334%
# Model's predicted likelihood that the image is a toaster: 0.001083472%
# Model's predicted likelihood that the image is a toaster: 0.001098696%
# Model's predicted likelihood that the image is a toaster: 0.0011141031%
# Model's predicted likelihood that the image is a toaster: 0.0011303568%
# Model's predicted likelihood that the image is a toaster: 0.0011471693%
# Model's predicted likelihood that the image is a toaster: 0.0011645564%
# Model's predicted likelihood that the image is a toaster: 0.0011951344%
# Model's predicted likelihood that the image is a toaster: 0.0012229013%
# Model's predicted likelihood that the image is a toaster: 0.0012504136%
# Model's predicted likelihood that the image is a toaster: 0.0012775904%
# Model's predicted likelihood that the image is a toaster: 0.001305694%
# Model's predicted likelihood that the image is a toaster: 0.0013342862%
# Model's predicted likelihood that the image is a toaster: 0.0013631182%
# Model's predicted likelihood that the image is a toaster: 0.0013940377%
# Model's predicted likelihood that the image is a toaster: 0.0014208502%
# Model's predicted likelihood that the image is a toaster: 0.0014472213%
# Model's predicted likelihood that the image is a toaster: 0.0014733794%
# Model's predicted likelihood that the image is a toaster: 0.0015008602%
# Model's predicted likelihood that the image is a toaster: 0.0015298048%
# Model's predicted likelihood that the image is a toaster: 0.0015597236%
# Model's predicted likelihood that the image is a toaster: 0.0015914848%
# Model's predicted likelihood that the image is a toaster: 0.0016240127%
# Model's predicted likelihood that the image is a toaster: 0.0016541839%
# Model's predicted likelihood that the image is a toaster: 0.0016864551%
# Model's predicted likelihood that the image is a toaster: 0.0017238899%
# Model's predicted likelihood that the image is a toaster: 0.0017607628%
# Model's predicted likelihood that the image is a toaster: 0.0017972572%
# Model's predicted likelihood that the image is a toaster: 0.0018348906%
# Model's predicted likelihood that the image is a toaster: 0.0018740124%
# Model's predicted likelihood that the image is a toaster: 0.0019133769%
# Model's predicted likelihood that the image is a toaster: 0.0019541001%
# Model's predicted likelihood that the image is a toaster: 0.0019957442%
# Model's predicted likelihood that the image is a toaster: 0.0020410944%
# Model's predicted likelihood that the image is a toaster: 0.0020880096%
# Model's predicted likelihood that the image is a toaster: 0.0021331196%
# Model's predicted likelihood that the image is a toaster: 0.0021784179%
# Model's predicted likelihood that the image is a toaster: 0.0022237171%
# Model's predicted likelihood that the image is a toaster: 0.0022711209%
# Model's predicted likelihood that the image is a toaster: 0.0023196857%
# Model's predicted likelihood that the image is a toaster: 0.0023681752%
# Model's predicted likelihood that the image is a toaster: 0.002415991%
# Model's predicted likelihood that the image is a toaster: 0.0024680507%
# Model's predicted likelihood that the image is a toaster: 0.0025219319%
# Model's predicted likelihood that the image is a toaster: 0.0025783504%
# Model's predicted likelihood that the image is a toaster: 0.0026380176%
# Model's predicted likelihood that the image is a toaster: 0.0026994843%
# Model's predicted likelihood that the image is a toaster: 0.0027601092%
# Model's predicted likelihood that the image is a toaster: 0.0028234392%
# Model's predicted likelihood that the image is a toaster: 0.0028907187%
# Model's predicted likelihood that the image is a toaster: 0.0029576713%
# Model's predicted likelihood that the image is a toaster: 0.0030283762%
# Model's predicted likelihood that the image is a toaster: 0.0031025931%
# Model's predicted likelihood that the image is a toaster: 0.0031906849%
# Model's predicted likelihood that the image is a toaster: 0.0032828673%
# Model's predicted likelihood that the image is a toaster: 0.0033821023%
# Model's predicted likelihood that the image is a toaster: 0.0034847726%
# Model's predicted likelihood that the image is a toaster: 0.0036004178%
# Model's predicted likelihood that the image is a toaster: 0.0037160877%
# Model's predicted likelihood that the image is a toaster: 0.0038366106%
# Model's predicted likelihood that the image is a toaster: 0.0039650349%
# Model's predicted likelihood that the image is a toaster: 0.0040880364%
# Model's predicted likelihood that the image is a toaster: 0.0042247881%
# Model's predicted likelihood that the image is a toaster: 0.004362598%
# Model's predicted likelihood that the image is a toaster: 0.004510253%
# Model's predicted likelihood that the image is a toaster: 0.0046725829%
# Model's predicted likelihood that the image is a toaster: 0.0048672078%
# Model's predicted likelihood that the image is a toaster: 0.0050655734%
# Model's predicted likelihood that the image is a toaster: 0.0052872289%
# Model's predicted likelihood that the image is a toaster: 0.0055197885%
# Model's predicted likelihood that the image is a toaster: 0.0057637953%
# Model's predicted likelihood that the image is a toaster: 0.0060307488%
# Model's predicted likelihood that the image is a toaster: 0.0062979532%
# Model's predicted likelihood that the image is a toaster: 0.0065471933%
# Model's predicted likelihood that the image is a toaster: 0.0067879002%
# Model's predicted likelihood that the image is a toaster: 0.0072000774%
# Model's predicted likelihood that the image is a toaster: 0.0075778647%
# Model's predicted likelihood that the image is a toaster: 0.0079950565%
# Model's predicted likelihood that the image is a toaster: 0.0083064078%
# Model's predicted likelihood that the image is a toaster: 0.0088973007%
# Model's predicted likelihood that the image is a toaster: 0.0094512288%
# Model's predicted likelihood that the image is a toaster: 0.010028873%
# Model's predicted likelihood that the image is a toaster: 0.010656536%
# Model's predicted likelihood that the image is a toaster: 0.011318832%
# Model's predicted likelihood that the image is a toaster: 0.012079616%
# Model's predicted likelihood that the image is a toaster: 0.012823356%
# Model's predicted likelihood that the image is a toaster: 0.013424398%
# Model's predicted likelihood that the image is a toaster: 0.014233524%
# Model's predicted likelihood that the image is a toaster: 0.015081346%
# Model's predicted likelihood that the image is a toaster: 0.01660837%
# Model's predicted likelihood that the image is a toaster: 0.017811581%
# Model's predicted likelihood that the image is a toaster: 0.01912962%
# Model's predicted likelihood that the image is a toaster: 0.020146013%
# Model's predicted likelihood that the image is a toaster: 0.021254254%
# Model's predicted likelihood that the image is a toaster: 0.023085816%
# Model's predicted likelihood that the image is a toaster: 0.023852229%
# Model's predicted likelihood that the image is a toaster: 0.025989977%
# Model's predicted likelihood that the image is a toaster: 0.029093382%
# Model's predicted likelihood that the image is a toaster: 0.03187962%
# Model's predicted likelihood that the image is a toaster: 0.036099594%
# Model's predicted likelihood that the image is a toaster: 0.041131509%
# Model's predicted likelihood that the image is a toaster: 0.048309751%
# Model's predicted likelihood that the image is a toaster: 0.05614268%
# Model's predicted likelihood that the image is a toaster: 0.05715969%
# Model's predicted likelihood that the image is a toaster: 0.078704854%
# Model's predicted likelihood that the image is a toaster: 0.098037731%
# Model's predicted likelihood that the image is a toaster: 0.10395022%
# Model's predicted likelihood that the image is a toaster: 0.20455292%
# Model's predicted likelihood that the image is a toaster: 0.15814753%
# Model's predicted likelihood that the image is a toaster: 0.25338405%
# Model's predicted likelihood that the image is a toaster: 0.38082011%
# Model's predicted likelihood that the image is a toaster: 0.54773423%
# Model's predicted likelihood that the image is a toaster: 0.6439534%
# Model's predicted likelihood that the image is a toaster: 1.1533051%
# Model's predicted likelihood that the image is a toaster: 0.085132947%
# Model's predicted likelihood that the image is a toaster: 1.3236014%
# Model's predicted likelihood that the image is a toaster: 1.5705843%
# Model's predicted likelihood that the image is a toaster: 0.037898796%
# Model's predicted likelihood that the image is a toaster: 0.15489318%
# Model's predicted likelihood that the image is a toaster: 1.3497056%
# Model's predicted likelihood that the image is a toaster: 1.6230995%
# Model's predicted likelihood that the image is a toaster: 0.83335778%
# Model's predicted likelihood that the image is a toaster: 22.255254%
